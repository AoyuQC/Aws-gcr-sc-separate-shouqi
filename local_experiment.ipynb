# %% [markdown]
# ## 进行本地模型测试
# ### 安装依赖包
# #### 需要提前在目录下安装libsndfile-1.0.28

# %%
# %%bash
# rm libsndfile-1.0.28.tar.gz
# rm -fr libsndfile-1.0.28
# wget http://www.mega-nerd.com/libsndfile/files/libsndfile-1.0.28.tar.gz
# tar -xzvf ./libsndfile-1.0.28.tar.gz
# cd ./libsndfile-1.0.28
# ./configure --prefix=/usr    \
#             --disable-static \
#             --docdir=/usr/share/doc/libsndfile-1.0.28 &&
# make
# sudo make install
# cd ..
# Out:
# libsndfile-1.0.28/
# libsndfile-1.0.28/aclocal.m4
# libsndfile-1.0.28/CMakeLists.txt
# libsndfile-1.0.28/CMake/
# libsndfile-1.0.28/CMake/build.cmake
# libsndfile-1.0.28/CMake/compiler_is_gcc.c
# libsndfile-1.0.28/CMake/file.cmake
# libsndfile-1.0.28/CMake/libsndfile.cmake
# libsndfile-1.0.28/CMake/check.cmake
# libsndfile-1.0.28/CMake/autogen.cmake
# libsndfile-1.0.28/CMake/have_decl_s_irgrp.c
# libsndfile-1.0.28/CMake/external_libs.cmake
# libsndfile-1.0.28/M4/
# libsndfile-1.0.28/M4/lt~obsolete.m4
# libsndfile-1.0.28/M4/clip_mode.m4
# libsndfile-1.0.28/M4/libtool.m4
# libsndfile-1.0.28/M4/llrint.m4
# libsndfile-1.0.28/M4/octave.m4
# libsndfile-1.0.28/M4/extra_pkg.m4
# libsndfile-1.0.28/M4/ltsugar.m4
# libsndfile-1.0.28/M4/add_cxxflags.m4
# libsndfile-1.0.28/M4/ltoptions.m4
# libsndfile-1.0.28/M4/clang.m4
# libsndfile-1.0.28/M4/add_cflags.m4
# libsndfile-1.0.28/M4/lrint.m4
# libsndfile-1.0.28/M4/stack_protect.m4
# libsndfile-1.0.28/M4/gcc_version.m4
# libsndfile-1.0.28/M4/Makefile.am
# libsndfile-1.0.28/M4/endian.m4
# libsndfile-1.0.28/M4/lrintf.m4
# libsndfile-1.0.28/M4/ltversion.m4
# libsndfile-1.0.28/M4/ax_add_fortify_source.m4
# libsndfile-1.0.28/M4/really_gcc.m4
# libsndfile-1.0.28/M4/Makefile.in
# libsndfile-1.0.28/M4/flexible_array.m4
# libsndfile-1.0.28/M4/visibility.m4
# libsndfile-1.0.28/M4/mkoctfile_version.m4
# libsndfile-1.0.28/examples/
# libsndfile-1.0.28/examples/make_sine.c
# libsndfile-1.0.28/examples/list_formats.c
# libsndfile-1.0.28/examples/sndfile-loopify.c
# libsndfile-1.0.28/examples/sndfile-to-text.c
# libsndfile-1.0.28/examples/Makefile.am
# libsndfile-1.0.28/examples/sndfilehandle.cc
# libsndfile-1.0.28/examples/generate.c
# libsndfile-1.0.28/examples/Makefile.in
# libsndfile-1.0.28/examples/sfprocess.c
# libsndfile-1.0.28/AUTHORS
# libsndfile-1.0.28/Octave/
# libsndfile-1.0.28/Octave/sndfile_play.m
# libsndfile-1.0.28/Octave/PKG_ADD
# libsndfile-1.0.28/Octave/octave_test.sh
# libsndfile-1.0.28/Octave/sndfile_load.m
# libsndfile-1.0.28/Octave/Makefile.am
# libsndfile-1.0.28/Octave/sndfile.cc
# libsndfile-1.0.28/Octave/sndfile_save.m
# libsndfile-1.0.28/Octave/Makefile.in
# libsndfile-1.0.28/Octave/octave_test.m
# libsndfile-1.0.28/libsndfile.spec.in
# libsndfile-1.0.28/src/
# libsndfile-1.0.28/src/create_symbols_file.py
# libsndfile-1.0.28/src/test_log_printf.c
# libsndfile-1.0.28/src/dwd.c
# libsndfile-1.0.28/src/nist.c
# libsndfile-1.0.28/src/sndfile.c
# libsndfile-1.0.28/src/sfconfig.h
# libsndfile-1.0.28/src/Symbols.gnu-binutils
# libsndfile-1.0.28/src/Symbols.darwin
# libsndfile-1.0.28/src/float32.c
# libsndfile-1.0.28/src/binheader_writef_check.py
# libsndfile-1.0.28/src/dither.c
# libsndfile-1.0.28/src/ogg.c
# libsndfile-1.0.28/src/sf_unistd.h
# libsndfile-1.0.28/src/w64.c
# libsndfile-1.0.28/src/audio_detect.c
# libsndfile-1.0.28/src/id3.c
# libsndfile-1.0.28/src/test_conversions.c
# libsndfile-1.0.28/src/interleave.c
# libsndfile-1.0.28/src/double64.c
# libsndfile-1.0.28/src/ima_oki_adpcm.h
# libsndfile-1.0.28/src/ima_oki_adpcm.c
# libsndfile-1.0.28/src/sndfile.hh
# libsndfile-1.0.28/src/test_strncpy_crlf.c
# libsndfile-1.0.28/src/rf64.c
# libsndfile-1.0.28/src/xi.c
# libsndfile-1.0.28/src/raw.c
# libsndfile-1.0.28/src/ogg_pcm.c
# libsndfile-1.0.28/src/ulaw.c
# libsndfile-1.0.28/src/sfendian.h
# libsndfile-1.0.28/src/ogg_opus.c
# libsndfile-1.0.28/src/G72x/
# libsndfile-1.0.28/src/G72x/g723_16.c
# libsndfile-1.0.28/src/G72x/README.original
# libsndfile-1.0.28/src/G72x/g723_40.c
# libsndfile-1.0.28/src/G72x/g72x_test.c
# libsndfile-1.0.28/src/G72x/g721.c
# libsndfile-1.0.28/src/G72x/g723_24.c
# libsndfile-1.0.28/src/G72x/README
# libsndfile-1.0.28/src/G72x/ChangeLog
# libsndfile-1.0.28/src/G72x/g72x_priv.h
# libsndfile-1.0.28/src/G72x/g72x.c
# libsndfile-1.0.28/src/G72x/g72x.h
# libsndfile-1.0.28/src/sds.c
# libsndfile-1.0.28/src/make-static-lib-hidden-privates.sh
# libsndfile-1.0.28/src/Makefile.am
# libsndfile-1.0.28/src/GSM610/
# libsndfile-1.0.28/src/GSM610/code.c
# libsndfile-1.0.28/src/GSM610/gsm_decode.c
# libsndfile-1.0.28/src/GSM610/short_term.c
# libsndfile-1.0.28/src/GSM610/gsm_option.c
# libsndfile-1.0.28/src/GSM610/long_term.c
# libsndfile-1.0.28/src/GSM610/table.c
# libsndfile-1.0.28/src/GSM610/add.c
# libsndfile-1.0.28/src/GSM610/COPYRIGHT
# libsndfile-1.0.28/src/GSM610/rpe.c
# libsndfile-1.0.28/src/GSM610/gsm_destroy.c
# libsndfile-1.0.28/src/GSM610/preprocess.c
# libsndfile-1.0.28/src/GSM610/README
# libsndfile-1.0.28/src/GSM610/ChangeLog
# libsndfile-1.0.28/src/GSM610/gsm610_priv.h
# libsndfile-1.0.28/src/GSM610/gsm_create.c
# libsndfile-1.0.28/src/GSM610/gsm_encode.c
# libsndfile-1.0.28/src/GSM610/lpc.c
# libsndfile-1.0.28/src/GSM610/config.h
# libsndfile-1.0.28/src/GSM610/decode.c
# libsndfile-1.0.28/src/GSM610/gsm.h
# libsndfile-1.0.28/src/chanmap.c
# libsndfile-1.0.28/src/chanmap.h
# libsndfile-1.0.28/src/alaw.c
# libsndfile-1.0.28/src/test_ima_oki_adpcm.c
# libsndfile-1.0.28/src/config.h.in
# libsndfile-1.0.28/src/txw.c
# libsndfile-1.0.28/src/gsm610.c
# libsndfile-1.0.28/src/ogg.h
# libsndfile-1.0.28/src/dwvw.c
# libsndfile-1.0.28/src/caf.c
# libsndfile-1.0.28/src/test_broadcast_var.c
# libsndfile-1.0.28/src/pvf.c
# libsndfile-1.0.28/src/wavlike.c
# libsndfile-1.0.28/src/cart.c
# libsndfile-1.0.28/src/version-metadata.rc
# libsndfile-1.0.28/src/paf.c
# libsndfile-1.0.28/src/mat4.c
# libsndfile-1.0.28/src/test_main.h
# libsndfile-1.0.28/src/ogg_speex.c
# libsndfile-1.0.28/src/broadcast.c
# libsndfile-1.0.28/src/htk.c
# libsndfile-1.0.28/src/test_audio_detect.c
# libsndfile-1.0.28/src/ircam.c
# libsndfile-1.0.28/src/ogg_vorbis.c
# libsndfile-1.0.28/src/version-metadata.rc.in
# libsndfile-1.0.28/src/test_cart_var.c
# libsndfile-1.0.28/src/wavlike.h
# libsndfile-1.0.28/src/avr.c
# libsndfile-1.0.28/src/windows.c
# libsndfile-1.0.28/src/ALAC/
# libsndfile-1.0.28/src/ALAC/ALACAudioTypes.h
# libsndfile-1.0.28/src/ALAC/dplib.h
# libsndfile-1.0.28/src/ALAC/ALACBitUtilities.c
# libsndfile-1.0.28/src/ALAC/ag_dec.c
# libsndfile-1.0.28/src/ALAC/ag_enc.c
# libsndfile-1.0.28/src/ALAC/aglib.h
# libsndfile-1.0.28/src/ALAC/dp_enc.c
# libsndfile-1.0.28/src/ALAC/alac_codec.h
# libsndfile-1.0.28/src/ALAC/alac_decoder.c
# libsndfile-1.0.28/src/ALAC/alac_encoder.c
# libsndfile-1.0.28/src/ALAC/ALACBitUtilities.h
# libsndfile-1.0.28/src/ALAC/shift.h
# libsndfile-1.0.28/src/ALAC/EndianPortable.h
# libsndfile-1.0.28/src/ALAC/matrixlib.h
# libsndfile-1.0.28/src/ALAC/matrix_enc.c
# libsndfile-1.0.28/src/ALAC/dp_dec.c
# libsndfile-1.0.28/src/ALAC/matrix_dec.c
# libsndfile-1.0.28/src/wve.c
# libsndfile-1.0.28/src/test_main.c
# libsndfile-1.0.28/src/mat5.c
# libsndfile-1.0.28/src/ms_adpcm.c
# libsndfile-1.0.28/src/ima_adpcm.c
# libsndfile-1.0.28/src/g72x.c
# libsndfile-1.0.28/src/file_io.c
# libsndfile-1.0.28/src/strings.c
# libsndfile-1.0.28/src/Symbols.static
# libsndfile-1.0.28/src/macos.c
# libsndfile-1.0.28/src/Makefile.in
# libsndfile-1.0.28/src/chunk.c
# libsndfile-1.0.28/src/mpc2k.c
# libsndfile-1.0.28/src/au.c
# libsndfile-1.0.28/src/flac.c
# libsndfile-1.0.28/src/test_endswap.tpl
# libsndfile-1.0.28/src/test_float.c
# libsndfile-1.0.28/src/test_binheader_writef.c
# libsndfile-1.0.28/src/pcm.c
# libsndfile-1.0.28/src/common.h
# libsndfile-1.0.28/src/alac.c
# libsndfile-1.0.28/src/test_file_io.c
# libsndfile-1.0.28/src/rx2.c
# libsndfile-1.0.28/src/sndfile.h.in
# libsndfile-1.0.28/src/voc.c
# libsndfile-1.0.28/src/vox_adpcm.c
# libsndfile-1.0.28/src/Symbols.os2
# libsndfile-1.0.28/src/command.c
# libsndfile-1.0.28/src/test_endswap.def
# libsndfile-1.0.28/src/test_endswap.c
# libsndfile-1.0.28/src/common.c
# libsndfile-1.0.28/src/svx.c
# libsndfile-1.0.28/src/libsndfile-1.def
# libsndfile-1.0.28/src/wav.c
# libsndfile-1.0.28/src/aiff.c
# libsndfile-1.0.28/src/sd2.c
# libsndfile-1.0.28/regtest/
# libsndfile-1.0.28/regtest/checksum.c
# libsndfile-1.0.28/regtest/database.c
# libsndfile-1.0.28/regtest/Makefile.am
# libsndfile-1.0.28/regtest/regtest.h
# libsndfile-1.0.28/regtest/Makefile.in
# libsndfile-1.0.28/regtest/sndfile-regtest.c
# libsndfile-1.0.28/Cfg/
# libsndfile-1.0.28/Cfg/compile
# libsndfile-1.0.28/Cfg/missing
# libsndfile-1.0.28/Cfg/config.sub
# libsndfile-1.0.28/Cfg/depcomp
# libsndfile-1.0.28/Cfg/config.guess
# libsndfile-1.0.28/Cfg/install-sh
# libsndfile-1.0.28/Cfg/ar-lib
# libsndfile-1.0.28/Cfg/ltmain.sh
# libsndfile-1.0.28/echo-install-dirs.in
# libsndfile-1.0.28/Makefile.am
# libsndfile-1.0.28/NEWS
# libsndfile-1.0.28/README
# libsndfile-1.0.28/ChangeLog
# libsndfile-1.0.28/sndfile.pc.in
# libsndfile-1.0.28/configure.ac
# libsndfile-1.0.28/man/
# libsndfile-1.0.28/man/sndfile-info.1
# libsndfile-1.0.28/man/sndfile-metadata-get.1
# libsndfile-1.0.28/man/sndfile-play.1
# libsndfile-1.0.28/man/sndfile-convert.1
# libsndfile-1.0.28/man/sndfile-interleave.1
# libsndfile-1.0.28/man/sndfile-concat.1
# libsndfile-1.0.28/man/Makefile.am
# libsndfile-1.0.28/man/sndfile-cmp.1
# libsndfile-1.0.28/man/sndfile-salvage.1
# libsndfile-1.0.28/man/Makefile.in
# libsndfile-1.0.28/tests/
# libsndfile-1.0.28/tests/pipe_test.tpl
# libsndfile-1.0.28/tests/ulaw_test.c
# libsndfile-1.0.28/tests/scale_clip_test.c
# libsndfile-1.0.28/tests/benchmark.tpl
# libsndfile-1.0.28/tests/chunk_test.c
# libsndfile-1.0.28/tests/dft_cmp.c
# libsndfile-1.0.28/tests/external_libs_test.c
# libsndfile-1.0.28/tests/utils.c
# libsndfile-1.0.28/tests/benchmark.c
# libsndfile-1.0.28/tests/floating_point_test.tpl
# libsndfile-1.0.28/tests/format_check_test.c
# libsndfile-1.0.28/tests/misc_test.c
# libsndfile-1.0.28/tests/rdwr_test.def
# libsndfile-1.0.28/tests/peak_chunk_test.c
# libsndfile-1.0.28/tests/write_read_test.tpl
# libsndfile-1.0.28/tests/lossy_comp_test.c
# libsndfile-1.0.28/tests/header_test.tpl
# libsndfile-1.0.28/tests/virtual_io_test.c
# libsndfile-1.0.28/tests/pcm_test.def
# libsndfile-1.0.28/tests/pedantic-header-test.sh.in
# libsndfile-1.0.28/tests/header_test.def
# libsndfile-1.0.28/tests/dwvw_test.c
# libsndfile-1.0.28/tests/multi_file_test.c
# libsndfile-1.0.28/tests/Makefile.am
# libsndfile-1.0.28/tests/pcm_test.c
# libsndfile-1.0.28/tests/string_test.c
# libsndfile-1.0.28/tests/aiff_rw_test.c
# libsndfile-1.0.28/tests/stdin_test.c
# libsndfile-1.0.28/tests/floating_point_test.def
# libsndfile-1.0.28/tests/long_read_write_test.c
# libsndfile-1.0.28/tests/sfversion.c
# libsndfile-1.0.28/tests/headerless_test.c
# libsndfile-1.0.28/tests/rdwr_test.c
# libsndfile-1.0.28/tests/command_test.c
# libsndfile-1.0.28/tests/generate.c
# libsndfile-1.0.28/tests/benchmark.def
# libsndfile-1.0.28/tests/utils.def
# libsndfile-1.0.28/tests/checksum_test.c
# libsndfile-1.0.28/tests/channel_test.c
# libsndfile-1.0.28/tests/cpp_test.cc
# libsndfile-1.0.28/tests/stdout_test.c
# libsndfile-1.0.28/tests/largefile_test.c
# libsndfile-1.0.28/tests/raw_test.c
# libsndfile-1.0.28/tests/write_read_test.def
# libsndfile-1.0.28/tests/pipe_test.c
# libsndfile-1.0.28/tests/win32_ordinal_test.c
# libsndfile-1.0.28/tests/ogg_test.c
# libsndfile-1.0.28/tests/dither_test.c
# libsndfile-1.0.28/tests/error_test.c
# libsndfile-1.0.28/tests/write_read_test.c
# libsndfile-1.0.28/tests/fix_this.c
# libsndfile-1.0.28/tests/scale_clip_test.def
# libsndfile-1.0.28/tests/pipe_test.def
# libsndfile-1.0.28/tests/win32_test.c
# libsndfile-1.0.28/tests/Makefile.in
# libsndfile-1.0.28/tests/generate.h
# libsndfile-1.0.28/tests/scale_clip_test.tpl
# libsndfile-1.0.28/tests/alaw_test.c
# libsndfile-1.0.28/tests/floating_point_test.c
# libsndfile-1.0.28/tests/test_wrapper.sh.in
# libsndfile-1.0.28/tests/dft_cmp.h
# libsndfile-1.0.28/tests/utils.h
# libsndfile-1.0.28/tests/stdio_test.c
# libsndfile-1.0.28/tests/rdwr_test.tpl
# libsndfile-1.0.28/tests/header_test.c
# libsndfile-1.0.28/tests/pcm_test.tpl
# libsndfile-1.0.28/tests/compression_size_test.c
# libsndfile-1.0.28/tests/utils.tpl
# libsndfile-1.0.28/tests/locale_test.c
# libsndfile-1.0.28/COPYING
# libsndfile-1.0.28/programs/
# libsndfile-1.0.28/programs/sndfile-salvage.c
# libsndfile-1.0.28/programs/sndfile-play.c
# libsndfile-1.0.28/programs/sndfile-deinterleave.c
# libsndfile-1.0.28/programs/sndfile-metadata-set.c
# libsndfile-1.0.28/programs/test-sndfile-metadata-set.py
# libsndfile-1.0.28/programs/sndfile-concat.c
# libsndfile-1.0.28/programs/Makefile.am
# libsndfile-1.0.28/programs/sndfile-cmp.c
# libsndfile-1.0.28/programs/sndfile-info.c
# libsndfile-1.0.28/programs/sndfile-convert.c
# libsndfile-1.0.28/programs/sndfile-metadata-get.c
# libsndfile-1.0.28/programs/Makefile.in
# libsndfile-1.0.28/programs/sndfile-interleave.c
# libsndfile-1.0.28/programs/common.h
# libsndfile-1.0.28/programs/sndfile-play-beos.cpp
# libsndfile-1.0.28/programs/common.c
# libsndfile-1.0.28/Makefile.in
# libsndfile-1.0.28/configure
# libsndfile-1.0.28/doc/
# libsndfile-1.0.28/doc/FAQ.html
# libsndfile-1.0.28/doc/lists.html
# libsndfile-1.0.28/doc/new_file_type.HOWTO
# libsndfile-1.0.28/doc/AUTHORS
# libsndfile-1.0.28/doc/octave.html
# libsndfile-1.0.28/doc/index.html
# libsndfile-1.0.28/doc/command.html
# libsndfile-1.0.28/doc/libsndfile.jpg
# libsndfile-1.0.28/doc/bugs.html
# libsndfile-1.0.28/doc/api.html
# libsndfile-1.0.28/doc/win32.html
# libsndfile-1.0.28/doc/Makefile.am
# libsndfile-1.0.28/doc/NEWS
# libsndfile-1.0.28/doc/README
# libsndfile-1.0.28/doc/ChangeLog
# libsndfile-1.0.28/doc/libsndfile.css.in
# libsndfile-1.0.28/doc/embedded_files.html
# libsndfile-1.0.28/doc/tutorial.html
# libsndfile-1.0.28/doc/Makefile.in
# libsndfile-1.0.28/doc/sndfile_info.html
# libsndfile-1.0.28/doc/libsndfile.css
# libsndfile-1.0.28/Scripts/
# libsndfile-1.0.28/Scripts/android-configure.sh
# libsndfile-1.0.28/Scripts/linux-to-win-cross-configure.sh
# libsndfile-1.0.28/Scripts/build-test-tarball.mk.in
# libsndfile-1.0.28/Win32/
# libsndfile-1.0.28/Win32/README-precompiled-dll.txt
# libsndfile-1.0.28/Win32/Makefile.am
# libsndfile-1.0.28/Win32/testprog.c
# libsndfile-1.0.28/Win32/Makefile.in
# libsndfile-1.0.28/INSTALL
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking target system type... x86_64-pc-linux-gnu
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... gawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking whether make supports nested variables... (cached) yes
# checking for style of include used by make... GNU
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking whether gcc understands -c and -o together... yes
# checking dependency style of gcc... gcc3
# checking for gcc option to accept ISO C99... -std=gnu99
# checking for gcc -std=gnu99 option to accept ISO Standard C... (cached) -std=gnu99
# checking how to run the C preprocessor... gcc -std=gnu99 -E
# checking for grep that handles long lines and -e... /bin/grep
# checking for egrep... /bin/grep -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking minix/config.h usability... no
# checking minix/config.h presence... no
# checking for minix/config.h... no
# checking whether it is safe to define __EXTENSIONS__... yes
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... gcc3
# checking whether we are using the CLANG C compiler... no
# checking for a sed that does not truncate output... /bin/sed
# checking for ar... ar
# checking the archiver (ar) interface... ar
# checking how to print strings... printf
# checking for a sed that does not truncate output... (cached) /bin/sed
# checking for fgrep... /bin/grep -F
# checking for ld used by gcc -std=gnu99... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 1572864
# checking how to convert x86_64-pc-linux-gnu file names to x86_64-pc-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-pc-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... no
# checking how to associate runtime and link libraries... printf %s\n
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from gcc -std=gnu99 object... ok
# checking for sysroot... no
# checking for a working dd... /bin/dd
# checking how to truncate binary pipes... /bin/dd bs=4096 count=1
# checking for mt... no
# checking if : is a manifest tool... no
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if gcc -std=gnu99 supports -fno-rtti -fno-exceptions... no
# checking for gcc -std=gnu99 option to produce PIC... -fPIC -DPIC
# checking if gcc -std=gnu99 PIC flag -fPIC -DPIC works... yes
# checking if gcc -std=gnu99 static flag -static works... no
# checking if gcc -std=gnu99 supports -c -o file.o... yes
# checking if gcc -std=gnu99 supports -c -o file.o... (cached) yes
# checking whether the gcc -std=gnu99 linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... no
# checking how to run the C++ preprocessor... g++ -E
# checking for ld used by g++... /usr/bin/ld -m elf_x86_64
# checking if the linker (/usr/bin/ld -m elf_x86_64) is GNU ld... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking for g++ option to produce PIC... -fPIC -DPIC
# checking if g++ PIC flag -fPIC -DPIC works... yes
# checking if g++ static flag -static works... no
# checking if g++ supports -c -o file.o... yes
# checking if g++ supports -c -o file.o... (cached) yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... (cached) GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking for windres... no
# checking whether ln -s works... yes
# checking for autogen... no
# checking for wine... no
# checking for xcode-select... no
# checking for ANSI C header files... (cached) yes
# checking endian.h usability... yes
# checking endian.h presence... yes
# checking for endian.h... yes
# checking byteswap.h usability... yes
# checking byteswap.h presence... yes
# checking for byteswap.h... yes
# checking locale.h usability... yes
# checking locale.h presence... yes
# checking for locale.h... yes
# checking sys/time.h usability... yes
# checking sys/time.h presence... yes
# checking for sys/time.h... yes
# checking for sys/wait.h that is POSIX.1 compatible... yes
# checking whether S_IRGRP is declared... yes
# checking whether the -Werror option is usable... yes
# checking for simple visibility declarations... yes
# checking size of wchar_t... 4
# checking size of short... 2
# checking size of int... 4
# checking size of long... 8
# checking size of float... 4
# checking size of double... 8
# checking size of void*... 8
# checking size of size_t... 8
# checking size of int64_t... 8
# checking size of long long... 8
# checking size of off_t... 8
# checking for ssize_t... yes
# checking processor byte ordering... little
# checking for malloc... yes
# checking for calloc... yes
# checking for realloc... yes
# checking for free... yes
# checking for open... yes
# checking for read... yes
# checking for write... yes
# checking for lseek... yes
# checking for lseek64... yes
# checking for fstat... yes
# checking for fstat64... yes
# checking for ftruncate... yes
# checking for fsync... yes
# checking for snprintf... yes
# checking for vsnprintf... yes
# checking for gmtime... yes
# checking for gmtime_r... yes
# checking for localtime... yes
# checking for localtime_r... yes
# checking for gettimeofday... yes
# checking for mmap... yes
# checking for getpagesize... yes
# checking for setlocale... yes
# checking for pipe... yes
# checking for waitpid... yes
# checking for floor in -lm... yes
# checking for floor... yes
# checking for ceil... yes
# checking for fmod... yes
# checking for lround... yes
# checking for lrint... yes
# checking for lrintf... yes
# checking for octave... no
# checking for mkoctfile... no
# checking for octave-config... no
# checking for pkg-config... /usr/bin/pkg-config
# checking pkg-config is at least version 0.9.0... yes
# checking for flac >= 1.3.1 ... no
# checking for ogg >= 1.1.3 ... no
# checking for vorbis >= 1.2.3 ... no
# checking for vorbisenc >= 1.2.3 ... no
#
#
# checking for sqlite3 >= 3.2 ... no
# checking processor clipping capabilities... none
# checking alsa/asoundlib.h usability... no
# checking alsa/asoundlib.h presence... no
# checking for alsa/asoundlib.h... no
# checking if gcc -std=gnu99 accepts -std=gnu99... yes
# checking for version of gcc -std=gnu99... 4.8.5
# checking if gcc -std=gnu99 accepts -Wextra... yes
# checking if gcc -std=gnu99 accepts -Wdeclaration-after-statement... yes
# checking if gcc -std=gnu99 accepts -Wpointer-arith... yes
# checking if g++ accepts -Wextra... yes
# checking if g++ accepts -Wpointer-arith... yes
# checking whether to add -D_FORTIFY_SOURCE=2 to CPPFLAGS... yes
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating src/Makefile
# config.status: creating man/Makefile
# config.status: creating examples/Makefile
# config.status: creating tests/Makefile
# config.status: creating regtest/Makefile
# config.status: creating M4/Makefile
# config.status: creating doc/Makefile
# config.status: creating Win32/Makefile
# config.status: creating Octave/Makefile
# config.status: creating programs/Makefile
# config.status: creating Makefile
# config.status: creating src/version-metadata.rc
# config.status: creating tests/test_wrapper.sh
# config.status: creating tests/pedantic-header-test.sh
# config.status: creating doc/libsndfile.css
# config.status: creating Scripts/build-test-tarball.mk
# config.status: creating libsndfile.spec
# config.status: creating sndfile.pc
# config.status: creating src/sndfile.h
# config.status: creating echo-install-dirs
# config.status: creating src/config.h
# config.status: executing depfiles commands
# config.status: executing libtool commands
#
# -=-=-=-=-=-=-=-=-=-= Configuration Complete =-=-=-=-=-=-=-=-=-=-
#
#   Configuration summary :
#
#     libsndfile version : .................. 1.0.28
#
#     Host CPU : ............................ x86_64
#     Host Vendor : ......................... pc
#     Host OS : ............................. linux-gnu
#
#     Experimental code : ................... no
#     Using ALSA in example programs : ...... no
#     External FLAC/Ogg/Vorbis : ............ no
#
#   Tools :
#
#     Compiler is Clang : ................... no
#     Compiler is GCC : ..................... yes
#     GCC version : ......................... 4.8.5
#     Sanitizer enabled : ................... no
#     Stack smash protection : .............. no
#
#   Installation directories :
#
#     Library directory : ................... /usr/lib
#     Program directory : ................... /usr/bin
#     Pkgconfig directory : ................. /usr/lib/pkgconfig
#     HTML docs directory : ................. /usr/share/doc/libsndfile-1.0.28
#
# Compiling some other packages against libsndfile may require
# the addition of '/usr/lib/pkgconfig' to the
# PKG_CONFIG_PATH environment variable.
#
# Making all in M4
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/M4'
# make[1]: Nothing to be done for `all'.
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/M4'
# Making all in Win32
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/Win32'
# make[1]: Nothing to be done for `all'.
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/Win32'
# Making all in src
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/src'
# make  all-am
# make[2]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/src'
#   CC       libsndfile_la-sndfile.lo
#   CC       libsndfile_la-aiff.lo
#   CC       libsndfile_la-au.lo
#   CC       libsndfile_la-avr.lo
#   CC       libsndfile_la-caf.lo
#   CC       libsndfile_la-dwd.lo
#   CC       libsndfile_la-flac.lo
#   CC       libsndfile_la-g72x.lo
#   CC       libsndfile_la-htk.lo
#   CC       libsndfile_la-ircam.lo
#   CC       libsndfile_la-macos.lo
#   CC       libsndfile_la-mat4.lo
#   CC       libsndfile_la-mat5.lo
#   CC       libsndfile_la-nist.lo
#   CC       libsndfile_la-paf.lo
#   CC       libsndfile_la-pvf.lo
#   CC       libsndfile_la-raw.lo
#   CC       libsndfile_la-rx2.lo
#   CC       libsndfile_la-sd2.lo
#   CC       libsndfile_la-sds.lo
#   CC       libsndfile_la-svx.lo
#   CC       libsndfile_la-txw.lo
#   CC       libsndfile_la-voc.lo
#   CC       libsndfile_la-wve.lo
#   CC       libsndfile_la-w64.lo
#   CC       libsndfile_la-wavlike.lo
#   CC       libsndfile_la-wav.lo
#   CC       libsndfile_la-xi.lo
#   CC       libsndfile_la-mpc2k.lo
#   CC       libsndfile_la-rf64.lo
#   CC       libsndfile_la-ogg_vorbis.lo
#   CC       libsndfile_la-ogg_speex.lo
#   CC       libsndfile_la-ogg_pcm.lo
#   CC       libsndfile_la-ogg_opus.lo
#   CC       GSM610/add.lo
#   CC       GSM610/code.lo
#   CC       GSM610/decode.lo
#   CC       GSM610/gsm_create.lo
#   CC       GSM610/gsm_decode.lo
#   CC       GSM610/gsm_destroy.lo
#   CC       GSM610/gsm_encode.lo
#   CC       GSM610/gsm_option.lo
#   CC       GSM610/long_term.lo
#   CC       GSM610/lpc.lo
#   CC       GSM610/preprocess.lo
#   CC       GSM610/rpe.lo
#   CC       GSM610/short_term.lo
#   CC       GSM610/table.lo
#   CCLD     GSM610/libgsm.la
#   CC       G72x/g721.lo
#   CC       G72x/g723_16.lo
#   CC       G72x/g723_24.lo
#   CC       G72x/g723_40.lo
#   CC       G72x/g72x.lo
#   CCLD     G72x/libg72x.la
#   CC       ALAC/ALACBitUtilities.lo
#   CC       ALAC/ag_dec.lo
#   CC       ALAC/ag_enc.lo
#   CC       ALAC/dp_dec.lo
#   CC       ALAC/dp_enc.lo
#   CC       ALAC/matrix_dec.lo
#   CC       ALAC/matrix_enc.lo
#   CC       ALAC/alac_decoder.lo
#   CC       ALAC/alac_encoder.lo
#   CCLD     ALAC/libalac.la
#   CC       common.lo
#   CC       file_io.lo
#   CC       command.lo
#   CC       pcm.lo
#   CC       ulaw.lo
#   CC       alaw.lo
#   CC       float32.lo
#   CC       double64.lo
#   CC       ima_adpcm.lo
#   CC       ms_adpcm.lo
#   CC       gsm610.lo
#   CC       dwvw.lo
#   CC       vox_adpcm.lo
#   CC       interleave.lo
#   CC       strings.lo
#   CC       dither.lo
#   CC       cart.lo
#   CC       broadcast.lo
#   CC       audio_detect.lo
#   CC       ima_oki_adpcm.lo
#   CC       alac.lo
#   CC       chunk.lo
#   CC       ogg.lo
#   CC       chanmap.lo
#   CC       windows.lo
#   CC       id3.lo
#   CCLD     libcommon.la
#   CCLD     libsndfile.la
# make[2]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/src'
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/src'
# Making all in examples
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/examples'
# make[1]: Nothing to be done for `all'.
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/examples'
# Making all in tests
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/tests'
# make[1]: Nothing to be done for `all'.
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/tests'
# Making all in man
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/man'
# ln -s ./sndfile-metadata-get.1 sndfile-metadata-set.1
# ln -s ./sndfile-interleave.1 sndfile-deinterleave.1
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/man'
# Making all in doc
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/doc'
# make[1]: Nothing to be done for `all'.
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/doc'
# Making all in regtest
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/regtest'
# make[1]: Nothing to be done for `all'.
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/regtest'
# Making all in programs
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/programs'
#   CC       sndfile-info.o
#   CC       common.o
#   CCLD     sndfile-info
#   CC       sndfile-play.o
#   CCLD     sndfile-play
#   CC       sndfile-convert.o
#   CCLD     sndfile-convert
#   CC       sndfile-cmp.o
#   CCLD     sndfile-cmp
#   CC       sndfile-metadata-set.o
#   CCLD     sndfile-metadata-set
#   CC       sndfile-metadata-get.o
#   CCLD     sndfile-metadata-get
#   CC       sndfile-interleave.o
#   CCLD     sndfile-interleave
#   CC       sndfile-deinterleave.o
#   CCLD     sndfile-deinterleave
#   CC       sndfile-concat.o
#   CCLD     sndfile-concat
#   CC       sndfile-salvage.o
#   CCLD     sndfile-salvage
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/programs'
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28'
# make[1]: Nothing to be done for `all-am'.
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28'
# Making install in M4
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/M4'
# make[2]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/M4'
# make[2]: Nothing to be done for `install-exec-am'.
# make[2]: Nothing to be done for `install-data-am'.
# make[2]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/M4'
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/M4'
# Making install in Win32
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/Win32'
# make[2]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/Win32'
# make[2]: Nothing to be done for `install-exec-am'.
# make[2]: Nothing to be done for `install-data-am'.
# make[2]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/Win32'
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/Win32'
# Making install in src
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/src'
# make[2]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/src'
#  /bin/mkdir -p '/usr/lib'
#  /bin/sh ../libtool   --mode=install /usr/bin/install -c   libsndfile.la '/usr/lib'
# libtool: install: /usr/bin/install -c .libs/libsndfile.so.1.0.28 /usr/lib/libsndfile.so.1.0.28
# libtool: install: (cd /usr/lib && { ln -s -f libsndfile.so.1.0.28 libsndfile.so.1 || { rm -f libsndfile.so.1 && ln -s libsndfile.so.1.0.28 libsndfile.so.1; }; })
# libtool: install: (cd /usr/lib && { ln -s -f libsndfile.so.1.0.28 libsndfile.so || { rm -f libsndfile.so && ln -s libsndfile.so.1.0.28 libsndfile.so; }; })
# libtool: install: /usr/bin/install -c .libs/libsndfile.lai /usr/lib/libsndfile.la
# libtool: finish: PATH="/sbin:/bin:/usr/sbin:/usr/bin:/sbin" ldconfig -n /usr/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
#  /bin/mkdir -p '/usr/include'
#  /usr/bin/install -c -m 644 sndfile.hh '/usr/include'
#  /bin/mkdir -p '/usr/include'
#  /usr/bin/install -c -m 644 sndfile.h '/usr/include'
# make[2]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/src'
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/src'
# Making install in examples
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/examples'
# make[2]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/examples'
# make[2]: Nothing to be done for `install-exec-am'.
# make[2]: Nothing to be done for `install-data-am'.
# make[2]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/examples'
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/examples'
# Making install in tests
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/tests'
# make[2]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/tests'
# make[2]: Nothing to be done for `install-exec-am'.
# make[2]: Nothing to be done for `install-data-am'.
# make[2]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/tests'
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/tests'
# Making install in man
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/man'
# make[2]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/man'
# make[2]: Nothing to be done for `install-exec-am'.
#  /bin/mkdir -p '/usr/share/man/man1'
#  /usr/bin/install -c -m 644 sndfile-info.1 sndfile-play.1 sndfile-convert.1 sndfile-cmp.1 sndfile-metadata-get.1 sndfile-metadata-set.1 sndfile-concat.1 sndfile-interleave.1 sndfile-deinterleave.1 sndfile-salvage.1 '/usr/share/man/man1'
# make[2]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/man'
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/man'
# Making install in doc
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/doc'
# make[2]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/doc'
# make[2]: Nothing to be done for `install-exec-am'.
#  /bin/mkdir -p '/usr/share/doc/libsndfile-1.0.28'
#  /usr/bin/install -c -m 644 index.html libsndfile.jpg libsndfile.css api.html command.html bugs.html sndfile_info.html new_file_type.HOWTO win32.html FAQ.html lists.html embedded_files.html octave.html tutorial.html '/usr/share/doc/libsndfile-1.0.28'
# make[2]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/doc'
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/doc'
# Making install in regtest
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/regtest'
# make[2]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/regtest'
# make[2]: Nothing to be done for `install-data-am'.
# make[2]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/regtest'
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/regtest'
# Making install in programs
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/programs'
# make[2]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/programs'
#  /bin/mkdir -p '/usr/bin'
#   /bin/sh ../libtool   --mode=install /usr/bin/install -c sndfile-info sndfile-play sndfile-convert sndfile-cmp sndfile-metadata-set sndfile-metadata-get sndfile-interleave sndfile-deinterleave sndfile-concat sndfile-salvage '/usr/bin'
# libtool: install: /usr/bin/install -c .libs/sndfile-info /usr/bin/sndfile-info
# libtool: install: /usr/bin/install -c .libs/sndfile-play /usr/bin/sndfile-play
# libtool: install: /usr/bin/install -c .libs/sndfile-convert /usr/bin/sndfile-convert
# libtool: install: /usr/bin/install -c .libs/sndfile-cmp /usr/bin/sndfile-cmp
# libtool: install: /usr/bin/install -c .libs/sndfile-metadata-set /usr/bin/sndfile-metadata-set
# libtool: install: /usr/bin/install -c .libs/sndfile-metadata-get /usr/bin/sndfile-metadata-get
# libtool: install: /usr/bin/install -c .libs/sndfile-interleave /usr/bin/sndfile-interleave
# libtool: install: /usr/bin/install -c .libs/sndfile-deinterleave /usr/bin/sndfile-deinterleave
# libtool: install: /usr/bin/install -c .libs/sndfile-concat /usr/bin/sndfile-concat
# libtool: install: /usr/bin/install -c .libs/sndfile-salvage /usr/bin/sndfile-salvage
# make[2]: Nothing to be done for `install-data-am'.
# make[2]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/programs'
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28/programs'
# make[1]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28'
# make[2]: Entering directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28'
# make[2]: Nothing to be done for `install-exec-am'.
#  /bin/mkdir -p '/usr/lib/pkgconfig'
#  /usr/bin/install -c -m 644 sndfile.pc '/usr/lib/pkgconfig'
# make[2]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28'
# make[1]: Leaving directory `/home/ec2-user/SageMaker/mlxj/Aws-gcr-sc-separate-shouqi/libsndfile-1.0.28'
# rm: cannot remove ‘libsndfile-1.0.28.tar.gz’: No such file or directory
# --2020-06-24 10:33:02--  http://www.mega-nerd.com/libsndfile/files/libsndfile-1.0.28.tar.gz
# Resolving www.mega-nerd.com (www.mega-nerd.com)... 97.107.128.207
# Connecting to www.mega-nerd.com (www.mega-nerd.com)|97.107.128.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1202833 (1.1M) [application/x-gzip]
# Saving to: ‘libsndfile-1.0.28.tar.gz’
#
#      0K .......... .......... .......... .......... ..........  4%  371K 3s
#     50K .......... .......... .......... .......... ..........  8%  738K 2s
#    100K .......... .......... .......... .......... .......... 12% 88.2M 1s
#    150K .......... .......... .......... .......... .......... 17% 35.3M 1s
#    200K .......... .......... .......... .......... .......... 21%  760K 1s
#    250K .......... .......... .......... .......... .......... 25%  212M 1s
#    300K .......... .......... .......... .......... .......... 29%  115M 1s
#    350K .......... .......... .......... .......... .......... 34% 50.8M 1s
#    400K .......... .......... .......... .......... .......... 38%  763K 1s
#    450K .......... .......... .......... .......... .......... 42%  148M 0s
#    500K .......... .......... .......... .......... .......... 46%  173M 0s
#    550K .......... .......... .......... .......... .......... 51%  209M 0s
#    600K .......... .......... .......... .......... .......... 55%  248M 0s
#    650K .......... .......... .......... .......... .......... 59%  210M 0s
#    700K .......... .......... .......... .......... .......... 63%  249M 0s
#    750K .......... .......... .......... .......... .......... 68% 88.9M 0s
#    800K .......... .......... .......... .......... .......... 72%  198M 0s
#    850K .......... .......... .......... .......... .......... 76%  767K 0s
#    900K .......... .......... .......... .......... .......... 80%  138M 0s
#    950K .......... .......... .......... .......... .......... 85%  204M 0s
#   1000K .......... .......... .......... .......... .......... 89%  165M 0s
#   1050K .......... .......... .......... .......... .......... 93%  302M 0s
#   1100K .......... .......... .......... .......... .......... 97%  333M 0s
#   1150K .......... .......... ....                            100%  317M=0.4s
#
# 2020-06-24 10:33:02 (2.82 MB/s) - ‘libsndfile-1.0.28.tar.gz’ saved [1202833/1202833]
#
# configure: WARNING: *** One or more of the external libraries (ie libflac, libogg and
# configure: WARNING: *** libvorbis) is either missing (possibly only the development
# configure: WARNING: *** headers) or is of an unsupported version.
# configure: WARNING: ***
# configure: WARNING: *** Unfortunately, for ease of maintenance, the external libs
# configure: WARNING: *** are an all or nothing affair.
# configure: WARNING: Touching files in directory tests/.

# %%
# !pip install nvidia-ml-py3
# !pip install torch==1.5.1
# !pip install numpy==1.16.4
# !pip install numba==0.48
# !pip install pytorch-lightning==0.7.6
# !pip install Cython==0.29.20
# !pip install asteroid==0.3.0
# !pip install sagemaker-inference==1.3.2.post0
# !pip install PyYAML==5.3.1
# Out:
# Requirement already satisfied: nvidia-ml-py3 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (7.352.0)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: torch==1.5.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (1.5.1)
# Requirement already satisfied: future in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from torch==1.5.1) (0.18.2)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from torch==1.5.1) (1.16.4)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy==1.16.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (1.16.4)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: numba==0.48 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (0.48.0)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from numba==0.48) (0.31.0)
# Requirement already satisfied: numpy>=1.15 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from numba==0.48) (1.16.4)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from numba==0.48) (46.1.3.post20200330)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: pytorch-lightning==0.7.6 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (0.7.6)
# Requirement already satisfied: numpy>=1.16.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pytorch-lightning==0.7.6) (1.16.4)
# Requirement already satisfied: future>=0.17.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pytorch-lightning==0.7.6) (0.18.2)
# Requirement already satisfied: torch>=1.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pytorch-lightning==0.7.6) (1.5.1)
# Requirement already satisfied: pyyaml>=3.13 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pytorch-lightning==0.7.6) (5.3.1)
# Requirement already satisfied: tensorboard>=1.14 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pytorch-lightning==0.7.6) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pytorch-lightning==0.7.6) (4.44.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (1.18.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (3.2.2)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (0.34.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (46.1.3.post20200330)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (0.4.1)
# Requirement already satisfied: grpcio>=1.24.3 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (1.30.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (1.6.0.post3)
# Requirement already satisfied: absl-py>=0.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (0.9.0)
# Requirement already satisfied: protobuf>=3.6.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (3.12.0)
# Requirement already satisfied: six>=1.10.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning==0.7.6) (1.14.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning==0.7.6) (4.1.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning==0.7.6) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning==0.7.6) (3.4.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard>=1.14->pytorch-lightning==0.7.6) (1.5.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch-lightning==0.7.6) (1.25.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch-lightning==0.7.6) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch-lightning==0.7.6) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch-lightning==0.7.6) (2.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->pytorch-lightning==0.7.6) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning==0.7.6) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard>=1.14->pytorch-lightning==0.7.6) (2.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->pytorch-lightning==0.7.6) (3.1.0)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: Cython==0.29.20 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (0.29.20)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: asteroid==0.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (0.3.0)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from asteroid==0.3.0) (1.4.1)
# Requirement already satisfied: soundfile in /home/ec2-user/.local/lib/python3.6/site-packages (from asteroid==0.3.0) (0.10.3.post1)
# Requirement already satisfied: pytorch-lightning in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from asteroid==0.3.0) (0.7.6)
# Requirement already satisfied: torch-optimizer in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from asteroid==0.3.0) (0.0.1a13)
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from asteroid==0.3.0) (1.5.1)
# Requirement already satisfied: pb-bss-eval in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from asteroid==0.3.0) (0.0.2)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from asteroid==0.3.0) (5.3.1)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from asteroid==0.3.0) (1.0.3)
# Requirement already satisfied: torch-stoi in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from asteroid==0.3.0) (0.1.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from asteroid==0.3.0) (1.16.4)
# Requirement already satisfied: cffi>=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from soundfile->asteroid==0.3.0) (1.14.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pytorch-lightning->asteroid==0.3.0) (4.44.1)
# Requirement already satisfied: tensorboard>=1.14 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pytorch-lightning->asteroid==0.3.0) (2.2.2)
# Requirement already satisfied: future>=0.17.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pytorch-lightning->asteroid==0.3.0) (0.18.2)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from torch-optimizer->asteroid==0.3.0) (0.1.1)
# Requirement already satisfied: einops in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pb-bss-eval->asteroid==0.3.0) (0.2.0)
# Requirement already satisfied: pesq in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pb-bss-eval->asteroid==0.3.0) (0.0.1)
# Requirement already satisfied: mir-eval in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pb-bss-eval->asteroid==0.3.0) (0.6)
# Requirement already satisfied: cached-property in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pb-bss-eval->asteroid==0.3.0) (1.5.1)
# Requirement already satisfied: pystoi in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pb-bss-eval->asteroid==0.3.0) (0.3.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pandas->asteroid==0.3.0) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pandas->asteroid==0.3.0) (2019.3)
# Requirement already satisfied: torchaudio in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from torch-stoi->asteroid==0.3.0) (0.5.1)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from cffi>=1.0->soundfile->asteroid==0.3.0) (2.20)
# Requirement already satisfied: markdown>=2.6.8 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (3.2.2)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (46.1.3.post20200330)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (1.6.0.post3)
# Requirement already satisfied: grpcio>=1.24.3 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (1.30.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (1.18.0)
# Requirement already satisfied: six>=1.10.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (1.14.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (0.34.2)
# Requirement already satisfied: absl-py>=0.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (0.9.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (2.23.0)
# Requirement already satisfied: protobuf>=3.6.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (3.12.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (1.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (3.4.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (4.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (2.9)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (2.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning->asteroid==0.3.0) (0.4.8)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: sagemaker-inference==1.3.2.post0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (1.3.2.post0)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker-inference==1.3.2.post0) (5.7.0)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker-inference==1.3.2.post0) (1.16.4)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker-inference==1.3.2.post0) (1.14.0)
# Requirement already satisfied: retrying==1.3.3 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker-inference==1.3.2.post0) (1.3.3)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: PyYAML==5.3.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (5.3.1)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.

# %%
import torch
from torch.optim import Adam
from torch.utils.data import DataLoader
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
import sys
import os
import time
import librosa
from scipy.signal import lfilter
import numpy as np
import scipy.io.wavfile
import soundfile as sf

from asteroid.data import LibriMix
from asteroid.engine.system import System
from asteroid.losses import PITLossWrapper, pairwise_neg_sisdr
from asteroid import ConvTasNet
from asteroid.models import ConvTasNet
from asteroid.models import DPRNNTasNet

import fnmatch, os, warnings

# %% [markdown]
# ### 定义帮助函数

# %%
def remove_pad(inputs, inputs_lengths):
    """
    Args:
        inputs: torch.Tensor, [B, C, T] or [B, T], B is batch size
        inputs_lengths: torch.Tensor, [B]
    Returns:
        results: a list containing B items, each item is [C, T], T varies
    """
    results = []
    dim = inputs.dim()
    if dim == 3:
        C = inputs.size(1)
    for input, length in zip(inputs, inputs_lengths):
        if dim == 3: # [B, C, T]
            results.append(input[:,:length].view(C, -1).cpu().numpy())
        elif dim == 2:  # [B, T]
            results.append(input[:length].view(-1).cpu().numpy())
    return results

def write(inputs, filename, sr=16000):
    librosa.output.write_wav(filename, inputs, sr)

def wavread(filename):
    fs, x = scipy.io.wavfile.read(filename)
    if np.issubdtype(x.dtype, np.integer):
        x = x / np.iinfo(x.dtype).max
    return x, fs

def wavwrite(filename, s, fs):
    if s.dtype != np.int16:
        s = np.array(s * 2**15, dtype=np.int16)
    if np.any(s > np.iinfo(np.int16).max) or np.any(s < np.iinfo(np.int16).min):
        warnings.warn('Warning: clipping detected when writing {}'.format(filename))
    scipy.io.wavfile.write(filename, fs, s)

def asl_meter(x, fs, nbits=16):
    '''Measure the Active Speech Level (ASR) of x following ITU-T P.56.
    If x is integer, it will be scaled to (-1, 1) according to nbits.
    '''

    if np.issubdtype(x.dtype, np.integer):
        x = x / 2**(nbits-1)

    # Constants
    MIN_LOG_OFFSET = 1e-20
    T = 0.03                # Time constant of smoothing in seconds
    g = np.exp(-1/(T*fs))
    H = 0.20                # Time of handover in seconds
    I = int(np.ceil(H*fs))
    M = 15.9                # Margin between threshold and ASL in dB

    a = np.zeros(nbits-1)                       # Activity count
    c = 0.5**np.arange(nbits-1, 0, step=-1)     # Threshold level
    h = np.ones(nbits)*I                        # Hangover count
    s = 0
    sq = 0
    p = 0
    q = 0
    asl = -100

    L = len(x)
    s = sum(abs(x))
    sq = sum(x**2)
    dclevel = s/np.arange(1, L+1)
    lond_term_level = 10*np.log10(sq/np.arange(1, L+1) + MIN_LOG_OFFSET)
    c_dB = 20*np.log10(c)

    for i in range(L):
        p = g * p + (1-g) * abs(x[i])
        q = g * q + (1-g) * p

        for j in range(nbits-1):
            if q >= c[j]:
                a[j] += 1
                h[j] = 0
            elif h[j] < I:
                a[j] += 1
                h[j] += 1

    a_dB = -100 * np.ones(nbits-1)

    for i in range(nbits-1):
        if a[i] != 0:
            a_dB[i] = 10*np.log10(sq/a[i])

    delta = a_dB - c_dB
    idx = np.where(delta <= M)[0]

    if len(idx) != 0:
        idx = idx[0]
        if idx > 1:
            asl = bin_interp(a_dB[idx], a_dB[idx-1], c_dB[idx], c_dB[idx-1], M)
        else:
            asl = a_dB[idx]

    return asl

def bin_interp(upcount, lwcount, upthr, lwthr, margin, tol=0.1):
    n_iter = 1
    if abs(upcount - upthr - margin) < tol:
        midcount = upcount
    elif abs(lwcount - lwthr - margin) < tol:
        midcount = lwcount
    else:
        midcount = (upcount + lwcount)/2
        midthr = (upthr + lwthr)/2
        diff = midcount - midthr - margin
        while abs(diff) > tol:
            n_iter += 1
            if n_iter > 20:
                tol *= 1.1
            if diff > tol:
                midcount = (upcount + midcount)/2
                midthr = (upthr + midthr)/2
            elif diff < -tol:
                midcount = (lwcount + midcount)/2
                midthr = (lwthr + midthr)/2
            diff = midcount - midthr - margin
    return midcount


def rms_energy(x):
    return 10*np.log10((1e-12 + x.dot(x))/len(x))

def preprocess_wav(filename):
    # filename = './1-20.wav'
    x, fs = wavread(filename)
    x_mirror = x
    # x = np.float32(x)
    # print(x.dtype)
    # N_dB = rms_energy(x_mirror)
    # S_dB = asl_meter(x, fs)
    # print(N_dB)
    # print(S_dB)

    # N_new = S_dB
    # x_mirror = 10**(N_new/20) * x_mirror / 10**(N_dB/20)
    asl_level = -26.0

    y = x + x_mirror
    y = y/10**(asl_meter(y, fs)/20) * 10**(asl_level/20)
    return x, fs

def pad_list(xs, pad_value):
    n_batch = len(xs)
    max_len = max(x.size(0) for x in xs)
    pad = xs[0].new(n_batch, max_len, * xs[0].size()[1:]).fill_(pad_value)
    for i in range(n_batch):
        pad[i, :xs[i].size(0)] = xs[i]
    return pad

def separate_process(x, model):
    ilens = np.array([x.shape[0]])

    # perform padding and convert to tensor
    pad_value = 0
    mixtures_pad = pad_list([torch.from_numpy(x).float()], pad_value)
    ilens = torch.from_numpy(ilens) 
    
    with torch.no_grad():
        mixture, mix_lengths = mixtures_pad.cuda(), ilens.cuda()
        # Forward
        estimate_source = model(mixture)  # [B, C, T]
        # Remove padding and flat
        print("wait.....")
        flat_estimate = remove_pad(estimate_source, mix_lengths)
    return flat_estimate[0]

# %% [markdown]
# ### 本地加载和推理实验

# %%
exp_dir = 'split_weight'
model_path = os.path.join(exp_dir, 'best_model.pth')
model = DPRNNTasNet.from_pretrained(model_path)
model.eval()
model.cuda()
# 10 seconds for each 
instance_time = 10
filename = './audio_raw_1-20_clip_0.wav'
# filename = './data/tt/mix/1-20-t-1_1-20-t-1_0dB.wav'

x, fs = preprocess_wav(filename)
instance_seg = instance_time * fs

l_x = len(x)
s_x = instance_seg
s1 = np.array([])
s2 = np.array([])
gl_i = 0
print('start timer')
Timer1 = time.time()
for start in range(0, l_x-s_x, s_x):
    flat_estimate = separate_process(x[start:start+s_x], model)
    s1 = np.concatenate([s1, flat_estimate[0]])
    s2 = np.concatenate([s2, flat_estimate[1]])
    gl_i = start+s_x
if gl_i < l_x:
    flat_estimate = separate_process(x[gl_i:], model)
    s1 = np.concatenate([s1, flat_estimate[0]])
    s2 = np.concatenate([s2, flat_estimate[1]])
print('finish {}'.format(time.time()-Timer1)) 
write(s1, './complete_split_s1.wav')
write(s2, './complete_split_s2.wav')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e98cc3adf151> in <module>
#       1 exp_dir = 'split_weight'
#       2 model_path = os.path.join(exp_dir, 'best_model.pth')
# ----> 3 model = DPRNNTasNet.from_pretrained(model_path)
#       4 model.eval()
#       5 model.cuda()
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/asteroid/models/base_models.py in from_pretrained(cls, pretrained_model_conf_or_path, *args, **kwargs)
#     122         """
#     123         if isinstance(pretrained_model_conf_or_path, str):
# --> 124             cached_model = cached_download(pretrained_model_conf_or_path)
#     125             conf = torch.load(cached_model, map_location='cpu')
#     126         else:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/asteroid/utils/hub_utils.py in cached_download(filename_or_url)
#      42     os.makedirs(cached_dir, exist_ok=True)
#      43     if not os.path.isfile(cached_path):
# ---> 44         hub.download_url_to_file(url, cached_path)
#      45         return cached_path
#      46     # It was already downloaded
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/hub.py in download_url_to_file(url, dst, hash_prefix, progress)
#     392     # We use a different API for python2 since urllib(2) doesn't recognize the CA
#     393     # certificates in older Python
# --> 394     u = urlopen(url)
#     395     meta = u.info()
#     396     if hasattr(meta, 'getheaders'):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     509         # accept a URL or a Request object
#     510         if isinstance(fullurl, str):
# --> 511             req = Request(fullurl, data)
#     512         else:
#     513             req = fullurl
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     327                  origin_req_host=None, unverifiable=False,
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#     331         self.unredirected_hdrs = {}
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/urllib/request.py in full_url(self, url)
#     353         self._full_url = unwrap(url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#     357     @full_url.deleter
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/urllib/request.py in _parse(self)
#     382         self.type, rest = splittype(self._full_url)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#     386         if self.host:
#
# ValueError: unknown url type: 'split_weight/best_model.pth'
